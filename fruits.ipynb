# %% [markdown]
# <a href="https://colab.research.google.com/github/AnhHao552001/BT-ANN_CNN/blob/main/fruits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPooling2D, Flatten
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.optimizers  import SGD
import numpy as np
from google.colab import drive

# %%
drive.mount('/content/drive')
folder= '/content/drive/MyDrive/BTAI/fruits/'
for i in range(9):
  plt.subplot(330+i+1)
  filename = folder + 'appleGolden'+ str(1000+i) +'.jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()
folder = '/content/drive/MyDrive/BTAI/fruits/'

photos, labels = list(), list()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
for file in listdir(folder):
  if file.startswith('appleGolden'):
    output = 0
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('appleRed'):
    output = 1
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('avocado'):
    output = 2
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('banana'):
    output = 3
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('cherry'):
    output = 4
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('coconut'):
    output = 5
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('kiwi'):
    output = 6
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('lemon'):
    output = 7
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('orange'):
    output = 8
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

for file in listdir(folder):
  if file.startswith('plum'):
    output = 9
    photo = load_img(folder+file,target_size=(200,200))
    photo = img_to_array(photo)
    photos.append(photo)
    labels.append(output)

# %%
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape,labels.shape)

save('Fruits_photos.npy', photos)
save('Fruits_labels.npy', labels)
# Out:
# (900, 200, 200, 3) (900,)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200,200, 3)))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(16, activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
history = model.fit(photos, labels, batch_size=64,epochs=20, verbose=1)
model.save('10fruits.h5')
# Out:
# Epoch 1/20
# 15/15 [==============================] - 14s 103ms/step - loss: 133.9770 - accuracy: 0.1500
# Epoch 2/20
# 15/15 [==============================] - 1s 86ms/step - loss: 0.7026 - accuracy: 0.7822
# Epoch 3/20
# 15/15 [==============================] - 1s 86ms/step - loss: 0.0216 - accuracy: 0.9956
# Epoch 4/20
# 15/15 [==============================] - 1s 85ms/step - loss: 0.0013 - accuracy: 1.0000
# Epoch 5/20
# 15/15 [==============================] - 1s 85ms/step - loss: 1.7701e-04 - accuracy: 1.0000
# Epoch 6/20
# 15/15 [==============================] - 1s 86ms/step - loss: 6.8419e-05 - accuracy: 1.0000
# Epoch 7/20
# 15/15 [==============================] - 1s 86ms/step - loss: 4.0406e-05 - accuracy: 1.0000
# Epoch 8/20
# 15/15 [==============================] - 1s 86ms/step - loss: 2.7816e-05 - accuracy: 1.0000
# Epoch 9/20
# 15/15 [==============================] - 1s 86ms/step - loss: 2.3163e-05 - accuracy: 1.0000
# Epoch 10/20
# ...

# %%
classes = ["appleGolden","appleRed","avocado","banana","cherry","coconut","kiwi","lemon","orange","plum"]
img = load_img('/content/drive/MyDrive/BTAI/fruits/banana1055.jpg', target_size=(200,200))
plt.imshow(img)

# %%
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.0720683  0.06684474 0.06628088 0.07537234 0.06341515 0.05251819
#   0.06638772 0.06534438 0.06400909 0.06547888 0.06108382 0.05889758
#   0.05222836 0.05747294 0.06088791 0.05170974]]
# 'banana'

# %%
classes = ["appleGolden","appleRed","avocado","banana","cherry","coconut","kiwi","lemon","orange","plum"]
img = load_img('/content/drive/MyDrive/BTAI/fruits/cherry1034.jpg', target_size=(200,200))
plt.imshow(img)

# %%
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.06727553 0.06469433 0.05773211 0.06129856 0.07565608 0.05737432
#   0.06978083 0.06475537 0.07081197 0.07063059 0.0565842  0.0607566
#   0.05691831 0.05602072 0.05826939 0.05144111]]
# 'cherry'

# %%
classes = ["appleGolden","appleRed","avocado","banana","cherry","coconut","kiwi","lemon","orange","plum"]
img = load_img('/content/drive/MyDrive/BTAI/fruits/lemon1036.jpg', target_size=(200,200))
plt.imshow(img)

# %%
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
y_classes
classes[y_classes[0]]
# Out:
# [[0.06923208 0.06182532 0.06276804 0.06661642 0.06701188 0.05342988
#   0.0682945  0.07208113 0.06453979 0.06716292 0.06318713 0.05782266
#   0.05612901 0.05674328 0.06083775 0.05231826]]
# 'lemon'
